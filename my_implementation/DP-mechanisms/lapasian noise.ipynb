# %%
import numpy as np

sensitivity = 1000
epsilon = 8

b = sensitivity/epsilon

n = 10 # Number of individuals

noise = np.random.laplace(0, b,n)
print(noise)
# Out:
# [ 0.39788453 -2.88778899  0.98919639 -5.68675733  0.09925176 -0.94180865
#  -2.2654877   5.42937161 -0.13478619 -0.70813682]
